# %% [markdown]
# # Домашняя работа №2

# %%
import numpy as np
from scipy.optimize import approx_fprime

# %%
import matplotlib.pyplot as plt
import numpy as np
import pylab
from scipy.misc import derivative
from scipy.optimize import minimize, approx_fprime, fmin, brute
from scipy.signal import find_peaks

# %matplotlib inline

# %%
from sympy import *
import pylab as plt

# %% [markdown]
# ### Задание 1

# %% [markdown]
# Посчитайте 1-ую и 2-ую производные функции (на бумажке):
#
# $f(x) = sin^2(2x+1)$
#
# f'(x) = 2*sin(2*x +1)*(sin(2*x+1)'
# (sin(2*x+1))' = (sin(2*x+1))'*(2*x+1)' = cos(2*x+1)*2
#
# f'(x) = 4*sin(2*x+1)*cos(2*x+1)
#
# f''(x) = 4*(cos(2x+1))' * sin(2x+1) + 4*cos(2x+1)*(sin(2x+1))' =
# = 4*(-2*sin(2x+1)*sin(2x+1)) + 4*(cos(2x+1)*2*cos(2x+1) =
# = -8*sin^2(2x+1) + 8*cos^2(2x+1)

# %%
x = Symbol('x')
y = np.power(sin(2*x+1), 2)
yprime = y.diff(x)
yprime
# Out:
# 4*sin(2*x + 1)*cos(2*x + 1)

# %%
z = 4*sin(2*x + 1)*cos(2*x + 1)
zprime = z.diff(x)
zprime
# Out:
# -8*sin(2*x + 1)**2 + 8*cos(2*x + 1)**2

# %% [markdown]
# ### Задание 2:
# Посчитайте частные производные функции в точкe
# (на бумажке или в LaTeX и на numpy):

# %% [markdown]
# $f(x,y)=2x^2y^3+1/x+y^2x+7$ в точке $(1,2)$

# %%
diff_x = 4*x*(y**3) + 1/(x**2) + y**2
diff_y = 6*(x**2)*(y**2) + 2*x*y
x = int(1)
y = int(2)
diff_x, diff_y
# почему diff_x выдает float?
# Out:
# (37.0, 28)

# %%
from sympy import *
x, y = symbols('x y')
diff(2*(x**2) * (y**3) + 1/x + (y**2)*x +7, x)
# Out:
# 4*x*y**3 + y**2 - 1/x**2

# %%
diff(2*(x**2) * (y**3) + 1/x + (y**2)*x +7, y)
# Out:
# 6*x**2*y**2 + 2*x*y

# %% [markdown]
# ### Задание 3

# %% [markdown]
# Найти точки минимума в следующих данных (колонка height):

# %%
import pandas as pd
data = pd.read_csv('video.csv')
data['height'] = data['height']*(-1)
data.head()
# Out:
#    sec   x1    y1    x2    y2  height
# 0    0  875  1411  1008  1835    -414
# 1    1  883  1377  1057  1873    -417
# 2    2  862  1397  1066  1872    -417
# 3    3  878  1394  1046  1875    -417
# 4    4  910  1378  1070  1866    -417

# %%
plt.figure(figsize=(25,8))
plt.plot(data.height)
plt.xlabel('время')
plt.ylabel('изменение высоты по времени')
# Out:
# Text(0, 0.5, 'изменение высоты по времени')

# %%
peaks, _ = find_peaks(data.height, prominence=1, width=20)
plt.plot(data.height)
plt.plot(peaks, data.height[peaks], "x")
plt.show()

# %%
p = peaks

# %%
peaks, _ = find_peaks(data.height, prominence=1, width=20)
data['height'] = data['height']*(-1)
plt.plot(data.height)
plt.plot(peaks, data.height[peaks], "x")
plt.show()

# %%
p
# Out:
# array([ 233,  244,  511,  750,  974, 1196])
