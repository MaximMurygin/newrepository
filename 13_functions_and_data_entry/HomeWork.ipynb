# %%
import pandas as pd

df = pd.read_csv('ratings.csv')


def classes(rating):
    if rating == 5.0 or rating == 4.5:
        return 'top'
    elif rating <= 4:
        return 'mid'
    elif rating <= 2:
        return 'low'


df['class'] = df['rating'].apply(classes)

print(df.head(30))
# Out:
#     userId  movieId  rating  timestamp class
# 0        1        1     4.0  964982703   mid
# 1        1        3     4.0  964981247   mid
# 2        1        6     4.0  964982224   mid
# 3        1       47     5.0  964983815   top
# 4        1       50     5.0  964982931   top
# 5        1       70     3.0  964982400   mid
# 6        1      101     5.0  964980868   top
# 7        1      110     4.0  964982176   mid
# 8        1      151     5.0  964984041   top
# 9        1      157     5.0  964984100   top
# 10       1      163     5.0  964983650   top
# 11       1      216     5.0  964981208   top
# 12       1      223     3.0  964980985   mid
# 13       1      231     5.0  964981179   top
# 14       1      235     4.0  964980908   mid
# 15       1      260     5.0  964981680   top
# 16       1      296     3.0  964982967   mid
# 17       1      316     3.0  964982310   mid
# 18       1      333     5.0  964981179   top
# 19       1      349     4.0  964982563   mid
# 20       1      356     4.0  964980962   mid
# 21       1      362     5.0  964982588   top
# 22       1      367     4.0  964981710   mid
# 23       1      423     3.0  964982363   mid
# 24       1      441     4.0  964980868   mid
# 25       1      457     5.0  964981909   top
# 26       1      480     4.0  964982346   mid
# 27       1      500     3.0  964981208   mid
# 28       1      527     5.0  964984002   top
# 29       1      543     4.0  964981179   mid

# %%
# Out:
#                           keyword     shows
# 0                              вк  64292779
# 1                   одноклассники  63810309
# 2                           порно  41747114
# 3                            ютуб  39995567
# 4                       вконтакте  21014195
# 5      одноклассники моя страница  19976138
# 6                            майл  15144673
# 7                           авито  14786593
# 8                      переводчик  14453469
# 9                          яндекс  13344734
# 10                сбербанк онлайн  10725673
# 11                           mail   7687204
# 12                           игры   6075762
# 13                        youtube   5729958
# 14         вконтакте моя страница   5971451
# 15                           секс   5431732
# 16                           гугл   5175471
# 17                             dr   4880955
# 18                    алиэкспресс   4879645
# 19                        рамблер   4540421
# 20                    фильмы 2016   4486635
# 21                         погода   4344510
# 22                             vk   4330448
# 23              ютуб видеохостинг   4215267
# 24                          дойки   4133424
# 25  одноклассники социальная сеть   4018230
# 26                       мультики   3866664
# 27                        контакт   3815111
# 28                        фейсбук   3669993
# 29                    порно видео   3858938
# 30                         google   3461040
# 31                        майл ру   3337779
# 32                             од   3178503
# 33                        новости   3137555
# 34             дом 2 свежие серии   3144489
# 35               игры для девочек   3053796
# 36                   порно онлайн   3179321
# 37                      инстаграм   2939686
# 38              переводчик онлайн   3882735
# 39                майл почта вход   2928262
# 40                    калькулятор   2827625
# 41                        mail ru   2707981
# 42                       сбербанк   2594497
# 43             mail ru почта вход   2576187
# 44                              ю   2479897
# 45                         vk com   2469370
# 46                             ок   2423704
# 47                        эротика   2410712
# 48                        авто ру   2398693
# 49                     почта майл   3386214

# %%
geo_data = {

    'Центр': ['москва', 'тула', 'ярославль'],

    'Северо-Запад': ['петербург', 'псков', 'мурманск'],

    'Дальний Восток': ['владивосток', 'сахалин', 'хабаровск']
}

# %%
def region(query):
    for k, v in geo_data.items():
        for i in query.split(' '):
            if i in str(v):
                return k


data['region'] = data['keyword'].apply(region)
data.head(50)
# Out:
#                           keyword     shows          region
# 0                              вк  64292779            None
# 1                   одноклассники  63810309            None
# 2                           порно  41747114            None
# 3                            ютуб  39995567            None
# 4                       вконтакте  21014195            None
# 5      одноклассники моя страница  19976138            None
# 6                            майл  15144673            None
# 7                           авито  14786593            None
# 8                      переводчик  14453469            None
# 9                          яндекс  13344734            None
# 10                сбербанк онлайн  10725673            None
# 11                           mail   7687204            None
# 12                           игры   6075762            None
# 13                        youtube   5729958            None
# 14         вконтакте моя страница   5971451            None
# 15                           секс   5431732            None
# 16                           гугл   5175471            None
# 17                             dr   4880955            None
# 18                    алиэкспресс   4879645            None
# 19                        рамблер   4540421            None
# 20                    фильмы 2016   4486635            None
# 21                         погода   4344510            None
# 22                             vk   4330448            None
# 23              ютуб видеохостинг   4215267            None
# 24                          дойки   4133424            None
# 25  одноклассники социальная сеть   4018230            None
# 26                       мультики   3866664            None
# 27                        контакт   3815111            None
# 28                        фейсбук   3669993            None
# 29                    порно видео   3858938            None
# 30                         google   3461040            None
# 31                        майл ру   3337779            None
# 32                             од   3178503            None
# 33                        новости   3137555            None
# 34             дом 2 свежие серии   3144489            None
# 35               игры для девочек   3053796            None
# 36                   порно онлайн   3179321            None
# 37                      инстаграм   2939686            None
# 38              переводчик онлайн   3882735            None
# 39                майл почта вход   2928262            None
# 40                    калькулятор   2827625            None
# 41                        mail ru   2707981            None
# 42                       сбербанк   2594497            None
# 43             mail ru почта вход   2576187            None
# 44                              ю   2479897            None
# 45                         vk com   2469370            None
# 46                             ок   2423704  Дальний Восток
# 47                        эротика   2410712            None
# 48                        авто ру   2398693            None
# 49                     почта майл   3386214            None
